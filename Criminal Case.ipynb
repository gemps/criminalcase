# %% [markdown]
# # Import Library

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Load Dataset

# %%
df18 = pd.read_csv('/Users/User/Documents/DATA SCIENCE/IYKRA/FP/crime2018.csv', encoding='latin-1')
df18
# Out:
#       INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# 0          I192077559          3115  Investigate Person
# 1          I192077332           619             Larceny
# 2          I192076660          2629          Harassment
# 3          I192075386          2629          Harassment
# 4          I192075335          3208       Property Lost
# ...               ...           ...                 ...
# 98883   I070720870-00           802      Simple Assault
# 98884   I070720870-00          3125     Warrant Arrests
# 98885   I060168073-00          1864      Drug Violation
# 98886   I060168073-00          1864      Drug Violation
# 98887   I060168073-00          3125     Warrant Arrests
#
#                                OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA  \
# 0                               INVESTIGATE PERSON       B3            468
# 1                               LARCENY ALL OTHERS      E18            496
# ...

# %%
df19 = pd.read_csv('/Users/User/Documents/DATA SCIENCE/IYKRA/FP/crime2019.csv', encoding='latin-1')
df19
# Out:
#       INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# 0           950485010          3125                 NaN
# 1           212025249          1107                 NaN
# 2           212022744          1107                 NaN
# 3           202007387           801                 NaN
# 4           212016533          1102                 NaN
# ...               ...           ...                 ...
# 19777       129099936          1106                 NaN
# 19778       129099920          3301                 NaN
# 19779       102096818          2905                 NaN
# 19780       102095489          3115                 NaN
# 19781       102091671          2647                 NaN
#
#                                      OFFENSE_DESCRIPTION DISTRICT  \
# 0      WARRANT ARREST - BOSTON WARRANT (MUST BE SUPPL...       A7
# 1                                  FRAUD - IMPERSONATION       A1
# 2                                  FRAUD - IMPERSONATION      C11
# ...

# %%
df20 = pd.read_csv('/Users/User/Documents/DATA SCIENCE/IYKRA/FP/crime2020.csv', encoding='latin-1')
df20
# Out:
# C:\Users\User\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#       INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# 0           854652314          3115                 NaN
# 1           457856954          3115                 NaN
# 2           302030654          1106                 NaN
# 3           212025777          1108                 NaN
# 4           212025557          2670                 NaN
# ...               ...           ...                 ...
# 70889        20063425          3114                 NaN
# 70890        20062356          1107                 NaN
# 70891        20046400          1501                 NaN
# 70892        20038446          1501                 NaN
# 70893        20030892           540                 NaN
#
# ...

# %% [markdown]
# # EDA

# %% [markdown]
# ## Data Understanding

# %%
code = pd.read_excel("OffenseCode.xlsx");
code
# Out:
#      CODE                                       NAME
# 0     612           LARCENY PURSE SNATCH - NO FORCE
# 1     613                        LARCENY SHOPLIFTING
# 2     615    LARCENY THEFT OF MV PARTS & ACCESSORIES
# 3    1731                                     INCEST
# 4    3111                  LICENSE PREMISE VIOLATION
# ..    ...                                        ...
# 571  1806  DRUGS - CLASS B TRAFFICKING OVER 18 GRAMS
# 572  1807  DRUGS - CLASS D TRAFFICKING OVER 50 GRAMS
# 573  1610    HUMAN TRAFFICKING - COMMERCIAL SEX ACTS
# 574  2010                              HOME INVASION
# 575  1620  HUMAN TRAFFICKING - INVOLUNTARY SERVITUDE
#
# [576 rows x 2 columns]

# %%
from PIL import Image, ImageDraw
img = Image.open("DataDict.PNG");
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=770x229 at 0x1D7749F2A30>

# %%
# Info df18
def check_df18(df18):
    print("##################### Shape #####################")
    print(df18.shape)
    print("##################### Types #####################")
    print(df18.dtypes)
    print("##################### Head #####################")
    print(df18.head())
    print("##################### Tail #####################")
    print(df18.tail())
    print("##################### NA #####################")
    print(df18.isnull().sum())
    print("##################### Quantiles #####################")
    print(df18.quantile([0, 0.05, 0.50, 0.95, 0.99, 1]).T)

check_df18(df18)
# Out:
# ##################### Shape #####################
# (98888, 17)
# ##################### Types #####################
# INCIDENT_NUMBER         object
# OFFENSE_CODE             int64
# OFFENSE_CODE_GROUP      object
# OFFENSE_DESCRIPTION     object
# DISTRICT                object
# REPORTING_AREA          object
# SHOOTING                object
# OCCURRED_ON_DATE        object
# YEAR                     int64
# MONTH                    int64
# DAY_OF_WEEK             object
# HOUR                     int64
# UCR_PART                object
# STREET                  object
# Lat                    float64
# Long                   float64
# Location                object
# dtype: object
# ##################### Head #####################
#   INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP OFFENSE_DESCRIPTION  \
# 0      I192077559          3115  Investigate Person  INVESTIGATE PERSON
# 1      I192077332           619             Larceny  LARCENY ALL OTHERS
# ...

# %%
# Info df19
def check_df19(df19):
    print("##################### Shape #####################")
    print(df19.shape)
    print("##################### Types #####################")
    print(df19.dtypes)
    print("##################### Head #####################")
    print(df19.head())
    print("##################### Tail #####################")
    print(df19.tail())
    print("##################### NA #####################")
    print(df19.isnull().sum())
    print("##################### Quantiles #####################")
    print(df19.quantile([0, 0.05, 0.50, 0.95, 0.99, 1]).T)

check_df19(df19)
# Out:
# ##################### Shape #####################
# (19782, 17)
# ##################### Types #####################
# INCIDENT_NUMBER         object
# OFFENSE_CODE             int64
# OFFENSE_CODE_GROUP     float64
# OFFENSE_DESCRIPTION     object
# DISTRICT                object
# REPORTING_AREA          object
# SHOOTING                 int64
# OCCURRED_ON_DATE        object
# YEAR                     int64
# MONTH                    int64
# DAY_OF_WEEK             object
# HOUR                     int64
# UCR_PART               float64
# STREET                  object
# Lat                    float64
# Long                   float64
# Location                object
# dtype: object
# ##################### Head #####################
#   INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# 0       950485010          3125                 NaN
# 1       212025249          1107                 NaN
# 2       212022744          1107                 NaN
# ...

# %%
# Info df20
def check_df20(df20):
    print("##################### Shape #####################")
    print(df20.shape)
    print("##################### Types #####################")
    print(df20.dtypes)
    print("##################### Head #####################")
    print(df20.head())
    print("##################### Tail #####################")
    print(df20.tail())
    print("##################### NA #####################")
    print(df20.isnull().sum())
    print("##################### Quantiles #####################")
    print(df20.quantile([0, 0.05, 0.50, 0.95, 0.99, 1]).T)

check_df20(df20)
# Out:
# ##################### Shape #####################
# (70894, 17)
# ##################### Types #####################
# INCIDENT_NUMBER         object
# OFFENSE_CODE             int64
# OFFENSE_CODE_GROUP     float64
# OFFENSE_DESCRIPTION     object
# DISTRICT                object
# REPORTING_AREA          object
# SHOOTING                 int64
# OCCURRED_ON_DATE        object
# YEAR                     int64
# MONTH                    int64
# DAY_OF_WEEK             object
# HOUR                     int64
# UCR_PART               float64
# STREET                  object
# Lat                    float64
# Long                   float64
# Location                object
# dtype: object
# ##################### Head #####################
#   INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# 0       854652314          3115                 NaN
# 1       457856954          3115                 NaN
# 2       302030654          1106                 NaN
# ...

# %% [markdown]
# ## Null Data

# %%
#showing the null data
is_NaN = df18.isnull()
row_has_NaN = is_NaN.any(axis=1)
rows_with_NaN = df18[row_has_NaN]

rows_with_NaN
# Out:
#       INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# 0          I192077559          3115  Investigate Person
# 1          I192077332           619             Larceny
# 2          I192076660          2629          Harassment
# 3          I192075386          2629          Harassment
# 4          I192075335          3208       Property Lost
# ...               ...           ...                 ...
# 98883   I070720870-00           802      Simple Assault
# 98884   I070720870-00          3125     Warrant Arrests
# 98885   I060168073-00          1864      Drug Violation
# 98886   I060168073-00          1864      Drug Violation
# 98887   I060168073-00          3125     Warrant Arrests
#
#                                OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA  \
# 0                               INVESTIGATE PERSON       B3            468
# 1                               LARCENY ALL OTHERS      E18            496
# ...

# %%
#showing the null data
nul = pd.isnull(df18["SHOOTING"])
null_value = df18[nul]
null_value
# Out:
#       INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# 0          I192077559          3115  Investigate Person
# 1          I192077332           619             Larceny
# 2          I192076660          2629          Harassment
# 3          I192075386          2629          Harassment
# 4          I192075335          3208       Property Lost
# ...               ...           ...                 ...
# 98883   I070720870-00           802      Simple Assault
# 98884   I070720870-00          3125     Warrant Arrests
# 98885   I060168073-00          1864      Drug Violation
# 98886   I060168073-00          1864      Drug Violation
# 98887   I060168073-00          3125     Warrant Arrests
#
#                                OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA  \
# 0                               INVESTIGATE PERSON       B3            468
# 1                               LARCENY ALL OTHERS      E18            496
# ...

# %%
#Check Missing Value
data_missing_value = df18.isnull().sum().reset_index()
data_missing_value.columns = ['feature','missing_value']
data_missing_value['percentage'] = round((data_missing_value['missing_value']/len(df18))*100,2)
data_missing_value = data_missing_value.sort_values('percentage', ascending=False).reset_index(drop=True)
data_missing_value = data_missing_value[data_missing_value['percentage']>0]
data_missing_value
# Out:
#     feature  missing_value  percentage
# 0  SHOOTING          98486       99.59
# 1      Long           6429        6.50
# 2       Lat           6429        6.50
# 3    STREET           1614        1.63
# 4  DISTRICT            682        0.69
# 5  UCR_PART             20        0.02

# %%
df18.SHOOTING.unique()
# Out:
# array([nan, 'Y'], dtype=object)

# %%
# For a better encoding, we replace nan value in SHOOTING with 0 and Y with 1
df18['SHOOTING'] = df18['SHOOTING'].replace(np.nan, 0)
df18['SHOOTING'] = df18['SHOOTING'].replace(['Y'],1)
df18.tail()
# Out:
#       INCIDENT_NUMBER  OFFENSE_CODE OFFENSE_CODE_GROUP  \
# 98883   I070720870-00           802     Simple Assault
# 98884   I070720870-00          3125    Warrant Arrests
# 98885   I060168073-00          1864     Drug Violation
# 98886   I060168073-00          1864     Drug Violation
# 98887   I060168073-00          3125    Warrant Arrests
#
#                                OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA  \
# 98883                            ASSAULT & BATTERY       B2            318
# 98884                               WARRANT ARREST       B2            318
# 98885  DRUGS - POSS CLASS D - INTENT MFR DIST DISP      E13            912
# 98886  DRUGS - POSS CLASS D - INTENT MFR DIST DISP      E13            912
# 98887                               WARRANT ARREST      E13            912
#
#        SHOOTING     OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  HOUR  \
# 98883         0  2018-12-13 00:00:00  2018     12    Thursday     0
# ...

# %%
# Delete character on INCIDENT_NUMBER
#df18['INCIDENT_NUMBER'] = df18['INCIDENT_NUMBER'].replace({'I':''}, regex=True)
#df18

# %%
df18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98888 entries, 0 to 98887
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   INCIDENT_NUMBER      98888 non-null  object
#  1   OFFENSE_CODE         98888 non-null  int64
#  2   OFFENSE_CODE_GROUP   98888 non-null  object
#  3   OFFENSE_DESCRIPTION  98888 non-null  object
#  4   DISTRICT             98206 non-null  object
#  5   REPORTING_AREA       98888 non-null  object
#  6   SHOOTING             98888 non-null  int64
#  7   OCCURRED_ON_DATE     98888 non-null  object
#  8   YEAR                 98888 non-null  int64
#  9   MONTH                98888 non-null  int64
#  10  DAY_OF_WEEK          98888 non-null  object
#  11  HOUR                 98888 non-null  int64
#  12  UCR_PART             98868 non-null  object
#  13  STREET               97274 non-null  object
#  14  Lat                  92459 non-null  float64
# ...

# %% [markdown]
# #### Cleaning df19

# %%
df19
# Out:
#       INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# 0           950485010          3125                 NaN
# 1           212025249          1107                 NaN
# 2           212022744          1107                 NaN
# 3           202007387           801                 NaN
# 4           212016533          1102                 NaN
# ...               ...           ...                 ...
# 19777       129099936          1106                 NaN
# 19778       129099920          3301                 NaN
# 19779       102096818          2905                 NaN
# 19780       102095489          3115                 NaN
# 19781       102091671          2647                 NaN
#
#                                      OFFENSE_DESCRIPTION DISTRICT  \
# 0      WARRANT ARREST - BOSTON WARRANT (MUST BE SUPPL...       A7
# 1                                  FRAUD - IMPERSONATION       A1
# 2                                  FRAUD - IMPERSONATION      C11
# ...

# %%
df19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19782 entries, 0 to 19781
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   INCIDENT_NUMBER      19782 non-null  object
#  1   OFFENSE_CODE         19782 non-null  int64
#  2   OFFENSE_CODE_GROUP   0 non-null      float64
#  3   OFFENSE_DESCRIPTION  19782 non-null  object
#  4   DISTRICT             19705 non-null  object
#  5   REPORTING_AREA       19782 non-null  object
#  6   SHOOTING             19782 non-null  int64
#  7   OCCURRED_ON_DATE     19782 non-null  object
#  8   YEAR                 19782 non-null  int64
#  9   MONTH                19782 non-null  int64
#  10  DAY_OF_WEEK          19782 non-null  object
#  11  HOUR                 19782 non-null  int64
#  12  UCR_PART             0 non-null      float64
#  13  STREET               19781 non-null  object
#  14  Lat                  19782 non-null  float64
# ...

# %%
df19.SHOOTING.unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# #### Cleaning df20

# %%
df20
# Out:
#       INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# 0           854652314          3115                 NaN
# 1           457856954          3115                 NaN
# 2           302030654          1106                 NaN
# 3           212025777          1108                 NaN
# 4           212025557          2670                 NaN
# ...               ...           ...                 ...
# 70889        20063425          3114                 NaN
# 70890        20062356          1107                 NaN
# 70891        20046400          1501                 NaN
# 70892        20038446          1501                 NaN
# 70893        20030892           540                 NaN
#
#                                      OFFENSE_DESCRIPTION DISTRICT  \
# 0                                     INVESTIGATE PERSON       B2
# 1                                     INVESTIGATE PERSON       B2
# 2                        FRAUD - CREDIT CARD / ATM FRAUD       D4
# ...

# %%
df20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70894 entries, 0 to 70893
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   INCIDENT_NUMBER      70894 non-null  object
#  1   OFFENSE_CODE         70894 non-null  int64
#  2   OFFENSE_CODE_GROUP   0 non-null      float64
#  3   OFFENSE_DESCRIPTION  70894 non-null  object
#  4   DISTRICT             70616 non-null  object
#  5   REPORTING_AREA       70894 non-null  object
#  6   SHOOTING             70894 non-null  int64
#  7   OCCURRED_ON_DATE     70894 non-null  object
#  8   YEAR                 70894 non-null  int64
#  9   MONTH                70894 non-null  int64
#  10  DAY_OF_WEEK          70894 non-null  object
#  11  HOUR                 70894 non-null  int64
#  12  UCR_PART             0 non-null      float64
#  13  STREET               70893 non-null  object
#  14  Lat                  70894 non-null  float64
# ...

# %% [markdown]
# ## Concatenate Data from 2018-2020

# %%
#concat the dataframe
df = pd.concat([df18, df19, df20])
df
# Out:
#       INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# 0          I192077559          3115  Investigate Person
# 1          I192077332           619             Larceny
# 2          I192076660          2629          Harassment
# 3          I192075386          2629          Harassment
# 4          I192075335          3208       Property Lost
# ...               ...           ...                 ...
# 70889        20063425          3114                 NaN
# 70890        20062356          1107                 NaN
# 70891        20046400          1501                 NaN
# 70892        20038446          1501                 NaN
# 70893        20030892           540                 NaN
#
#                                      OFFENSE_DESCRIPTION DISTRICT  \
# 0                                     INVESTIGATE PERSON       B3
# 1                                     LARCENY ALL OTHERS      E18
# 2                                             HARASSMENT       E5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 189564 entries, 0 to 70893
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   INCIDENT_NUMBER      189564 non-null  object
#  1   OFFENSE_CODE         189564 non-null  int64
#  2   OFFENSE_CODE_GROUP   98888 non-null   object
#  3   OFFENSE_DESCRIPTION  189564 non-null  object
#  4   DISTRICT             188527 non-null  object
#  5   REPORTING_AREA       189564 non-null  object
#  6   SHOOTING             189564 non-null  int64
#  7   OCCURRED_ON_DATE     189564 non-null  object
#  8   YEAR                 189564 non-null  int64
#  9   MONTH                189564 non-null  int64
#  10  DAY_OF_WEEK          189564 non-null  object
#  11  HOUR                 189564 non-null  int64
#  12  UCR_PART             98868 non-null   object
#  13  STREET               187948 non-null  object
#  14  Lat                  183135 non-null  float64
# ...

# %% [markdown]
# ## Statistika Deskriptif

# %% [markdown]
# **Numerical Data**

# %%
df[['OFFENSE_CODE','SHOOTING','YEAR','MONTH','HOUR']].describe()
# Out:
#         OFFENSE_CODE       SHOOTING           YEAR          MONTH  \
# count  189564.000000  189564.000000  189564.000000  189564.000000
# mean     2330.227607       0.009073    2018.852324       7.022757
# std      1212.336767       0.094822       0.934795       3.488644
# min       111.000000       0.000000    2018.000000       1.000000
# 25%      1102.000000       0.000000    2018.000000       4.000000
# 50%      3005.000000       0.000000    2018.000000       7.000000
# 75%      3201.000000       0.000000    2020.000000      10.000000
# max     99999.000000       1.000000    2020.000000      12.000000
#
#                 HOUR
# count  189564.000000
# mean       12.928557
# std         6.359623
# min         0.000000
# 25%         9.000000
# 50%        14.000000
# 75%        18.000000
# max        23.000000

# %% [markdown]
# **Non Numerical Data**

# %%
df[['INCIDENT_NUMBER','OFFENSE_CODE_GROUP','OFFENSE_DESCRIPTION','DISTRICT','REPORTING_AREA','DAY_OF_WEEK','UCR_PART','Location']].describe()
# Out:
#        INCIDENT_NUMBER               OFFENSE_CODE_GROUP OFFENSE_DESCRIPTION  \
# count           189564                            98888              189564
# unique          177410                               61                 231
# top         I182051210  Motor Vehicle Accident Response  INVESTIGATE PERSON
# freq                14                            11647               11807
#
#        DISTRICT REPORTING_AREA DAY_OF_WEEK    UCR_PART  \
# count    188527         189564      189564       98868
# unique       13            880           7           4
# top          B2                     Friday  Part Three
# freq      28934          18176       28689       51068
#
#                         Location
# count                     189564
# unique                     26568
# top     (0.00000000, 0.00000000)
# freq                        6429

# %%
df.duplicated().sum()
# Out:
# 161

# %% [markdown]
# ## Remove Duplicate

# %% [markdown]
# **We remove duplicated incident number with same offense description**

# %%
df.drop_duplicates(subset=['INCIDENT_NUMBER', 'OFFENSE_DESCRIPTION'], keep='first',inplace=True)
df
# Out:
#       INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# 0          I192077559          3115  Investigate Person
# 1          I192077332           619             Larceny
# 2          I192076660          2629          Harassment
# 3          I192075386          2629          Harassment
# 4          I192075335          3208       Property Lost
# ...               ...           ...                 ...
# 70889        20063425          3114                 NaN
# 70890        20062356          1107                 NaN
# 70891        20046400          1501                 NaN
# 70892        20038446          1501                 NaN
# 70893        20030892           540                 NaN
#
#                                      OFFENSE_DESCRIPTION DISTRICT  \
# 0                                     INVESTIGATE PERSON       B3
# 1                                     LARCENY ALL OTHERS      E18
# 2                                             HARASSMENT       E5
# ...

# %%
cek_duplikat = df['INCIDENT_NUMBER'].duplicated()
df [cek_duplikat].sort_values(by='INCIDENT_NUMBER')
# Out:
#       INCIDENT_NUMBER  OFFENSE_CODE        OFFENSE_CODE_GROUP  \
# 98887   I060168073-00          3125           Warrant Arrests
# 98882   I070720870-00           802            Simple Assault
# 98877   I070720870-00          3125           Warrant Arrests
# 98872   I140212767-00          3125           Warrant Arrests
# 98868   I142004681-00          3125           Warrant Arrests
# ...               ...           ...                       ...
# 115        I192036339          3112  Landlord/Tenant Disputes
# 81         I192044773          1001            Counterfeiting
# 48         I192057434           619                   Larceny
# 36         I192061201          3109  Police Service Incidents
# 33         I192061552           619                   Larceny
#
#                      OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA  SHOOTING  \
# 98887                     WARRANT ARREST      E13            912         0
# ...

# %%
df.tail(50)
# Out:
#       INCIDENT_NUMBER  OFFENSE_CODE OFFENSE_CODE_GROUP  \
# 70844       200152365           614                NaN
# 70845       200151157          1402                NaN
# 70846       200146784          3018                NaN
# 70847       200144443          3501                NaN
# 70848       200132385          1402                NaN
# 70849       200123328          3006                NaN
# 70850       200120821          2648                NaN
# 70851       200115995           801                NaN
# 70852       200113807          2646                NaN
# 70853       200103456          3115                NaN
# 70854       200081904          3831                NaN
# 70855       200078230          3207                NaN
# 70856       200073244          3114                NaN
# 70857       200072656          3114                NaN
# 70858       200067285          3005                NaN
# 70859       200063566           613                NaN
# ...

# %% [markdown]
# ## Missing Value

# %%
# Showing blank value in REPORTING_AREA
df.loc[df['REPORTING_AREA'] == ' ']
# Out:
#       INCIDENT_NUMBER  OFFENSE_CODE    OFFENSE_CODE_GROUP  \
# 49         I192057266          1107                 Fraud
# 124        I192033783           619               Larceny
# 125        I192033774          3201         Property Lost
# 179        I192024207           619               Larceny
# 199        I192021161          3114  Investigate Property
# ...               ...           ...                   ...
# 70858       200067285          3005                   NaN
# 70869       200024506          3115                   NaN
# 70870       200013539           619                   NaN
# 70875       200003262          3126                   NaN
# 70879       192059632          3125                   NaN
#
#                                      OFFENSE_DESCRIPTION DISTRICT  \
# 49                                 FRAUD - IMPERSONATION      NaN
# 124                                   LARCENY ALL OTHERS       C6
# 125                                      PROPERTY - LOST       B2
# ...

# %%
df['REPORTING_AREA'] = df['REPORTING_AREA'].replace([' '],np.nan)
df.tail(50)
# Out:
#       INCIDENT_NUMBER  OFFENSE_CODE OFFENSE_CODE_GROUP  \
# 70844       200152365           614                NaN
# 70845       200151157          1402                NaN
# 70846       200146784          3018                NaN
# 70847       200144443          3501                NaN
# 70848       200132385          1402                NaN
# 70849       200123328          3006                NaN
# 70850       200120821          2648                NaN
# 70851       200115995           801                NaN
# 70852       200113807          2646                NaN
# 70853       200103456          3115                NaN
# 70854       200081904          3831                NaN
# 70855       200078230          3207                NaN
# 70856       200073244          3114                NaN
# 70857       200072656          3114                NaN
# 70858       200067285          3005                NaN
# 70859       200063566           613                NaN
# ...

# %%
df.loc[df['DISTRICT'].isnull()]
# Out:
#       INCIDENT_NUMBER  OFFENSE_CODE               OFFENSE_CODE_GROUP  \
# 49         I192057266          1107                            Fraud
# 313        I192010508          3831  Motor Vehicle Accident Response
# 393        I192007129          2647                            Other
# 416        I192006194          3802  Motor Vehicle Accident Response
# 546        I192002348           614       Larceny From Motor Vehicle
# ...               ...           ...                              ...
# 70578       202000350          3831                              NaN
# 70784        20183767          1501                              NaN
# 70829       200239007           616                              NaN
# 70874       200003822          2619                              NaN
# 70883       122031190          3006                              NaN
#
#                                      OFFENSE_DESCRIPTION DISTRICT  \
# 49                                 FRAUD - IMPERSONATION      NaN
# ...

# %%
data_missing_value = df.isnull().sum().reset_index()
data_missing_value.columns = ['feature','missing_value']
data_missing_value = data_missing_value.sort_values('missing_value', ascending=False).reset_index(drop=True)
data_missing_value = data_missing_value[data_missing_value['missing_value']>0]
data_missing_value
# Out:
#               feature  missing_value
# 0            UCR_PART          90696
# 1  OFFENSE_CODE_GROUP          90676
# 2      REPORTING_AREA          18168
# 3                Long           6421
# 4                 Lat           6421
# 5              STREET           1611
# 6            DISTRICT           1037

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

x = data_missing_value['feature']
y = data_missing_value['missing_value']
plt.figure(figsize=(10,10))
barh = plt.bar(x=x, height=y, data=data_missing_value, 
       color = '#842e2e', 
       edgecolor= '#2e2e2e',
       linewidth = 2) 

plt.title('Missing Value', fontsize = 16)
plt.ylabel('Count Missing Value', fontsize=14)
plt.xlabel('Feature', fontsize=14)

x_numbers = range(len(x))
for i in x_numbers:
    plt.text(x = x_numbers[i]-0.18, y = y[i]+20, s = str(round(y[i],2)),size = 15)
plt.tight_layout
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# Too many data missing in **UCR_Part** then we drop it. Also we drop **OFFENSE_CODE_GROUP** because it can replace with OFFENSE_CODE. And for **Reporting Area**, we agreed to drop that column, because it can be represented by DISTRICT.
#
# For **Long, Lat, Stret** and **District**, we drop it.

# %%
df.drop(df.columns[[2,5,12]], axis=1, inplace=True)
df.dropna(subset=['Long','Lat','STREET','DISTRICT'], inplace=True)
df
# Out:
#       INCIDENT_NUMBER  OFFENSE_CODE  \
# 0          I192077559          3115
# 1          I192077332           619
# 2          I192076660          2629
# 3          I192075386          2629
# 4          I192075335          3208
# ...               ...           ...
# 70889        20063425          3114
# 70890        20062356          1107
# 70891        20046400          1501
# 70892        20038446          1501
# 70893        20030892           540
#
#                                      OFFENSE_DESCRIPTION DISTRICT  SHOOTING  \
# 0                                     INVESTIGATE PERSON       B3         0
# 1                                     LARCENY ALL OTHERS      E18         0
# 2                                             HARASSMENT       E5         0
# 3                                             HARASSMENT       A1         0
# 4                                     PROPERTY - MISSING       D4         0
# ...

# %% [markdown]
# ## Univariate Analysis

# %%
numerics = ['int8','int16', 'int32', 'int64', 'float16', 'float32', 'float64']
data_num = df.select_dtypes(include=numerics)
data_num.head()
# Out:
#    OFFENSE_CODE  SHOOTING  YEAR  MONTH  HOUR        Lat       Long
# 0          3115         0  2018      4     9  42.279971 -71.095534
# 1           619         0  2018      3     8  42.269224 -71.120853
# 2          2629         0  2018     10    12  42.290765 -71.130211
# 3          2629         0  2018      4     8  42.355264 -71.050988
# 4          3208         0  2018      1     0  42.353522 -71.072838

# %%
data_cat = df.select_dtypes(include=['object'])
data_cat.head()
# Out:
#   INCIDENT_NUMBER OFFENSE_DESCRIPTION DISTRICT     OCCURRED_ON_DATE  \
# 0      I192077559  INVESTIGATE PERSON       B3  2018-04-30 09:00:00
# 1      I192077332  LARCENY ALL OTHERS      E18  2018-03-06 08:00:00
# 2      I192076660          HARASSMENT       E5  2018-10-31 12:00:00
# 3      I192075386          HARASSMENT       A1  2018-04-09 08:43:00
# 4      I192075335  PROPERTY - MISSING       D4  2018-01-01 00:00:00
#
#   DAY_OF_WEEK            STREET                     Location
# 0      Monday       HAZLETON ST  (42.27997063, -71.09553354)
# 1     Tuesday     HYDE PARK AVE  (42.26922388, -71.12085347)
# 2   Wednesday       PRIMROSE ST  (42.29076521, -71.13021098)
# 3      Monday      ATLANTIC AVE  (42.35526402, -71.05098788)
# 4      Monday  COMMONWEALTH AVE  (42.35352153, -71.07283786)

# %%
features = ['YEAR', 'MONTH', 'HOUR']
plt.figure(figsize=(15, 15))
for i in range(0, len(features)):
    plt.subplot(2, 8, i+1)
    sns.boxplot(df[features[i]],color='green',orient='v')
    plt.tight_layout()
    
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
data_catvis = data_cat.drop(['INCIDENT_NUMBER'], axis=1)
data_cb=data_catvis.nunique().reset_index()
data_cb.columns=['Variabel','Jumlah']
x = data_cb['Variabel']
y = data_cb['Jumlah']
plt.figure(figsize=(15,8))
barh = plt.bar(x=x, height=y, data=data_cb,
               color = '#876e88',
               edgecolor='black',
               linewidth =2)
plt.title('Jumlah Unique Variabel Categori')
plt.ylabel('Jumlah', fontsize=14)
plt.xlabel('Variabel', fontsize=14)

plt.show()

# %%
sns.countplot(y='OFFENSE_DESCRIPTION', data=data_cat, order = data_cat['OFFENSE_DESCRIPTION'].value_counts().iloc[:10].index,
                palette=sns.color_palette("Reds_d", n_colors=10, desat=1))
plt.title('Case Distribution')
plt.ylabel('Case')
plt.xlabel('Frequency')
plt.xticks(rotation = 0)
plt.show()

# %%
sns.countplot(y='DISTRICT', data=data_cat, order = data_cat['DISTRICT'].value_counts().iloc[:10].index,
                palette=sns.color_palette("Reds_d", n_colors=10, desat=1))
plt.title('Case Distribution')
plt.ylabel('District')
plt.xlabel('Frequency')
plt.xticks(rotation = 0)
plt.show()

# %%
sns.countplot(y='DAY_OF_WEEK', data=data_cat, order = data_cat['DAY_OF_WEEK'].value_counts().iloc[:7].index,
                palette=sns.color_palette("Reds_d", n_colors=10, desat=1))
plt.title('Case Distribution')
plt.ylabel('Day')
plt.xlabel('Frequency')
plt.xticks(rotation = 0)
plt.show()

# %%
sns.countplot(y='STREET', data=data_cat, order = data_cat['STREET'].value_counts().iloc[:10].index,
                palette=sns.color_palette("Reds_d", n_colors=10, desat=1))
plt.title('Case Distribution')
plt.ylabel('Street Name')
plt.xlabel('Frequency')
plt.xticks(rotation = 0)
plt.show()

# %%
sns.countplot(y='Location', data=data_cat, order = data_cat['Location'].value_counts().iloc[:10].index,
                palette=sns.color_palette("Reds_d", n_colors=10, desat=1))
plt.title('Case Distribution')
plt.ylabel('Location')
plt.xlabel('Frequency')
plt.xticks(rotation = 0)
plt.show()

# %% [markdown]
# # Project Objectives

# %% [markdown]
# ## Objectives 1

# %% [markdown]
# Distrik dengan angka kriminalitas tertinggi

# %%
#all year
mostcrime= df.groupby(['DISTRICT']).count().sort_values(by='INCIDENT_NUMBER', ascending=False).reset_index()
mostcrime = mostcrime [['DISTRICT','INCIDENT_NUMBER']]
mostcrime.head(3)
# Out:
#   DISTRICT  INCIDENT_NUMBER
# 0       B2            27695
# 1      C11            23804
# 2       D4            23074

# %%
# 2018
crime18 = df18.groupby(['DISTRICT']).count().sort_values(by='INCIDENT_NUMBER', ascending=False).reset_index()
crime18 = crime18 [['DISTRICT','INCIDENT_NUMBER']].head(1)

# 2018
crime19 = df19.groupby(['DISTRICT']).count().sort_values(by='INCIDENT_NUMBER', ascending=False).reset_index()
crime19 = crime19 [['DISTRICT','INCIDENT_NUMBER']].head(1)

# 2018
crime20 = df20.groupby(['DISTRICT']).count().sort_values(by='INCIDENT_NUMBER', ascending=False).reset_index()
crime20 = crime20 [['DISTRICT','INCIDENT_NUMBER']].head(1)

print(crime18)
print(crime19)
print(crime20)
# Out:
#   DISTRICT  INCIDENT_NUMBER
# 0       B2            15658
#   DISTRICT  INCIDENT_NUMBER
# 0       B2             2834
#   DISTRICT  INCIDENT_NUMBER
# 0       B2            10442

# %% [markdown]
# Dari tahun 2018-2020, district B2 adalah district terbanyak kasus kriminal

# %% [markdown]
# ## Objectives 2

# %%
# Query the database for Quantity greater than 3
df_1920 = df.query('YEAR == 2019 | YEAR == 2020')

# Filter out labels of interest
case_filter = df_1920.filter(['OFFENSE_CODE', 'YEAR', 'INCIDENT_NUMBER'])

# Group the value according to a condition
case1920 = case_filter.groupby( ['OFFENSE_CODE', 'YEAR'] ).count().reset_index()
case1920
# Out:
#      OFFENSE_CODE  YEAR  INCIDENT_NUMBER
# 0             111  2019                5
# 1             111  2020               52
# 2             300  2019                2
# 3             301  2019              243
# 4             301  2020              807
# ..            ...   ...              ...
# 246          3830  2019               88
# 247          3830  2020              237
# 248          3831  2019             1200
# 249          3831  2020             3577
# 250         99999  2020                1
#
# [251 rows x 3 columns]

# %%
case20 = case1920.drop_duplicates('OFFENSE_CODE', keep='first')
obj2 = case20[case20.YEAR != 2019].sort_values(by='INCIDENT_NUMBER', ascending=False)
obj2
# Out:
#      OFFENSE_CODE  YEAR  INCIDENT_NUMBER
# 118          2618  2020               24
# 188          3123  2020               15
# 123          2628  2020                6
# 126          2642  2020                6
# 51            990  2020                1
# 250         99999  2020                1

# %%
code.loc[(code['CODE'] == 2618) | (code['CODE'] == 3123) | (code['CODE'] == 2628) | (code['CODE'] == 2642) | (code['CODE'] == 990),:]
# Out:
#      CODE                             NAME
# 22   2628              OBSCENE PHONE CALLS
# 73   2642                TRUANCY / RUNAWAY
# 128  2618   EXPLOSIVES - POSSESSION OR USE
# 129  3123  EXPLOSIVES - TURNED IN OR FOUND
# 395  2618   EXPLOSIVES - POSSESSION OR USE
# 396  3123  EXPLOSIVES - TURNED IN OR FOUND
# 453  2628              OBSCENE PHONE CALLS
# 504  2642                          TRUANCY

# %% [markdown]
# ## Objectives 3

# %%
df['OCCURRED_ON_DATE'] = pd.to_datetime(df['OCCURRED_ON_DATE'])
df
# Out:
#       INCIDENT_NUMBER  OFFENSE_CODE  \
# 0          I192077559          3115
# 1          I192077332           619
# 2          I192076660          2629
# 3          I192075386          2629
# 4          I192075335          3208
# ...               ...           ...
# 70889        20063425          3114
# 70890        20062356          1107
# 70891        20046400          1501
# 70892        20038446          1501
# 70893        20030892           540
#
#                                      OFFENSE_DESCRIPTION DISTRICT  SHOOTING  \
# 0                                     INVESTIGATE PERSON       B3         0
# 1                                     LARCENY ALL OTHERS      E18         0
# 2                                             HARASSMENT       E5         0
# 3                                             HARASSMENT       A1         0
# 4                                     PROPERTY - MISSING       D4         0
# ...

# %%
import datetime as dt
df['OCCURRED_ON_DATE'] = pd.to_datetime(df['OCCURRED_ON_DATE'])

# %%
# new feature
from pandas.api.types import CategoricalDtype
def create_features(df):
    df['dayofweek'] = df['OCCURRED_ON_DATE'].dt.dayofweek
    df['quarter'] = df['OCCURRED_ON_DATE'].dt.quarter
    df['dayofyear'] = df['OCCURRED_ON_DATE'].dt.dayofyear
    df['dayofmonth'] = df['OCCURRED_ON_DATE'].dt.day
    df['weekofyear'] = df['OCCURRED_ON_DATE'].dt.weekofyear
    
    X = df[['dayofweek','quarter','dayofyear',
            'dayofmonth','weekofyear']]
    return X
create_features(df).head()

# CategoricalDytpe
df.quarter    = df.quarter.astype(CategoricalDtype())
df.dayofweek    = df.dayofweek.astype(CategoricalDtype())
df.dayofyear    = df.dayofyear.astype(CategoricalDtype())
df.dayofmonth    = df.dayofmonth.astype(CategoricalDtype())


df.head()
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE OFFENSE_DESCRIPTION DISTRICT  SHOOTING  \
# 0      I192077559          3115  INVESTIGATE PERSON       B3         0
# 1      I192077332           619  LARCENY ALL OTHERS      E18         0
# 2      I192076660          2629          HARASSMENT       E5         0
# 3      I192075386          2629          HARASSMENT       A1         0
# 4      I192075335          3208  PROPERTY - MISSING       D4         0
#
#      OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  HOUR            STREET  \
# 0 2018-04-30 09:00:00  2018      4      Monday     9       HAZLETON ST
# 1 2018-03-06 08:00:00  2018      3     Tuesday     8     HYDE PARK AVE
# 2 2018-10-31 12:00:00  2018     10   Wednesday    12       PRIMROSE ST
# 3 2018-04-09 08:43:00  2018      4      Monday     8      ATLANTIC AVE
# 4 2018-01-01 00:00:00  2018      1      Monday     0  COMMONWEALTH AVE
#
#          Lat       Long                     Location dayofweek quarter  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 181710 entries, 0 to 70893
# Data columns (total 19 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   INCIDENT_NUMBER      181710 non-null  object
#  1   OFFENSE_CODE         181710 non-null  int64
#  2   OFFENSE_DESCRIPTION  181710 non-null  object
#  3   DISTRICT             181710 non-null  object
#  4   SHOOTING             181710 non-null  int64
#  5   OCCURRED_ON_DATE     181710 non-null  datetime64[ns]
#  6   YEAR                 181710 non-null  int64
#  7   MONTH                181710 non-null  int64
#  8   DAY_OF_WEEK          181710 non-null  object
#  9   HOUR                 181710 non-null  int64
#  10  STREET               181710 non-null  object
#  11  Lat                  181710 non-null  float64
#  12  Long                 181710 non-null  float64
#  13  Location             181710 non-null  object
# ...

# %%
mostweek = df.loc[(df['weekofyear'] >=40) & (df['weekofyear'] <= 45),:]
mostweek.groupby(['OFFENSE_CODE']).count().sort_values(by='INCIDENT_NUMBER', ascending=False).reset_index().head(2)
#mostcrime = mostcrime [['DISTRICT','INCIDENT_NUMBER']]
#mostcrime.head(3)
# Out:
#    OFFENSE_CODE  INCIDENT_NUMBER  OFFENSE_DESCRIPTION  DISTRICT  SHOOTING  \
# 0          3115             1767                 1767      1767      1767
# 1          3831             1512                 1512      1512      1512
#
#    OCCURRED_ON_DATE  YEAR  MONTH  DAY_OF_WEEK  HOUR  STREET   Lat  Long  \
# 0              1767  1767   1767         1767  1767    1767  1767  1767
# 1              1512  1512   1512         1512  1512    1512  1512  1512
#
#    Location  dayofweek  quarter  dayofyear  dayofmonth  weekofyear
# 0      1767       1767     1767       1767        1767        1767
# 1      1512       1512     1512       1512        1512        1512

# %%
code.loc[(code['CODE'] == 3115) | (code['CODE'] == 3831),:]
# Out:
#      CODE                                   NAME
# 151  3115                     INVESTIGATE PERSON
# 180  3831  M/V - LEAVING SCENE - PROPERTY DAMAGE
# 427  3115                     INVESTIGATE PERSON

# %% [markdown]
# Jika investigasi bukan termasuk tindak kriminal, maka **"LEAVING SCENE - PROPERTY DAMAGE"** adalah kejahatan terbanyak di minggu 40-45

# %% [markdown]
# ## Objectives 4

# %%
leastweekend = df.loc[(df['DAY_OF_WEEK'] == 'Saturday') | (df['DAY_OF_WEEK'] == 'Sunday'),:]
#leastweekend [['DAY_OF_WEEK']]
leastweekend.groupby(['DISTRICT']).count().sort_values(by='INCIDENT_NUMBER', ascending=True).reset_index().head(1)
# Out:
#    DISTRICT  INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_DESCRIPTION  SHOOTING  \
# 0  External               69            69                   69        69
#
#    OCCURRED_ON_DATE  YEAR  MONTH  DAY_OF_WEEK  HOUR  STREET  Lat  Long  \
# 0                69    69     69           69    69      69   69    69
#
#    Location  dayofweek  quarter  dayofyear  dayofmonth  weekofyear
# 0        69         69       69         69          69          69

# %% [markdown]
# ## Objectives 5

# %%
mostweekday = df.loc[(df['DAY_OF_WEEK'] == 'Monday') | (df['DAY_OF_WEEK'] == 'Tuesday') | (df['DAY_OF_WEEK'] == 'Wednesday') | (df['DAY_OF_WEEK'] == 'Thursday') | (df['DAY_OF_WEEK'] == 'Friday'),:]
#mostweekday [['DAY_OF_WEEK']]
mostweekday.groupby(['DISTRICT']).count().sort_values(by='INCIDENT_NUMBER', ascending=False).reset_index().head(1)
# Out:
#   DISTRICT  INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_DESCRIPTION  SHOOTING  \
# 0       B2            20637         20637                20637     20637
#
#    OCCURRED_ON_DATE   YEAR  MONTH  DAY_OF_WEEK   HOUR  STREET    Lat   Long  \
# 0             20637  20637  20637        20637  20637   20637  20637  20637
#
#    Location  dayofweek  quarter  dayofyear  dayofmonth  weekofyear
# 0     20637      20637    20637      20637       20637       20637

# %% [markdown]
# # Machine Learning

# %%
df
# Out:
#       INCIDENT_NUMBER  OFFENSE_CODE  \
# 0          I192077559          3115
# 1          I192077332           619
# 2          I192076660          2629
# 3          I192075386          2629
# 4          I192075335          3208
# ...               ...           ...
# 70889        20063425          3114
# 70890        20062356          1107
# 70891        20046400          1501
# 70892        20038446          1501
# 70893        20030892           540
#
#                                      OFFENSE_DESCRIPTION DISTRICT  SHOOTING  \
# 0                                     INVESTIGATE PERSON       B3         0
# 1                                     LARCENY ALL OTHERS      E18         0
# 2                                             HARASSMENT       E5         0
# 3                                             HARASSMENT       A1         0
# 4                                     PROPERTY - MISSING       D4         0
# ...
